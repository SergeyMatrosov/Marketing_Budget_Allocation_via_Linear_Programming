# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.plot([6000, 6000], [0, 10000], 'r')
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.plot([6000, 6000], [0, 10000], 'b')
plt.plot([6000, 6000, 10000, 6000], [0, 4000, 0, 0], 'r')
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.plot([6000, 6000], [0, 10000], 'b')
plt.plot([6000, 6000, 10000, 6000], [0, 4000, 0, 0], 'r')
plt.plot([6000, 0], [0, 3500], 'c:')
plt.text(2200, 3000, '700',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.plot([6000, 6000], [0, 10000], 'b')
plt.plot([6000, 6000, 10000, 6000], [0, 4000, 0, 0], 'r')
plt.plot([6000, 0], [0, 3500], 'c:')
plt.text(2200, 3000, '700',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.plot([10000, 0], [0, 6250], 'c:')
plt.text(2500, 5600, '1250',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')

# %%
plt.plot([10000,0], [0,10000], 'b')
plt.plot([0,10000], [0,0], 'b')
plt.plot([0, 0], [0,10000], 'b')
plt.plot([6000, 6000], [0, 10000], 'b')
plt.plot([6000, 6000, 10000, 6000], [0, 4000, 0, 0], 'r')
plt.plot([6000, 0], [0, 3500], 'c:')
plt.text(2200, 3000, '700',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.plot([10000, 0], [0, 6250], 'c:')
plt.text(2500, 5600, '1250',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.plot([12400, 0], [0, 7750], 'c')
plt.text(2500, 7100, '1550',
         rotation=-25,
         horizontalalignment='center',
         verticalalignment='top',
         multialignment='center')
plt.plot([6000], [4000], 'y.', markersize=20)
plt.xlabel('Display')
plt.ylabel('Search')
# Out:
# Text(0, 0.5, 'Search')
